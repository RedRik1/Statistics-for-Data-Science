# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Exercise 1:
# Get total profit of all months and show line plot with the following Style properties
# Generated line plot must include following Style properties: –
#
# Line Style dotted and Line-color should be red
#
# Show legend at the lower right location.
#
# X label name = Month Number
#
# Y label name = Sold units number
#
# Add a circle marker.
#
# Line marker color as read
#
# Line width should be 3
#
# The line plot graph should look like this.
#
# ![image.png](data:image/png;base64,...)

# %%
# Code Here
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv('/content/drive/MyDrive/Classroom/CSE303/company_sales_data.csv')
months = df['month_number'].tolist()
rsum = df.sum(axis=1)
ax = rsum.plot(linestyle='--',color='red',marker = 'o',
         markerfacecolor = 'black', markersize = 8)

ax.set_xlabel('Month number')
ax.set_ylabel('Profit in Dollar')
ax.set_title('Company sales data of last year')
ax.legend(['Profit data of last year'],loc='lower right')
plt.xticks(months)
plt.show()

# %% [markdown]
# # Exercise 2:
# Read all product sales data and show it  using a multiline plot
# Display the number of units sold per month for each product using multiline plots. (i.e., Separate Plotline for each product ).
#
# The graph should look like this.
#
# ![image.png](data:image/png;base64,...)

# %%
df.head()
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0             1       2500      1500        5200         9200     1200
# 1             2       2630      1200        5100         6100     2100
# 2             3       2140      1340        4550         9550     3550
# 3             4       3400      1130        5870         8870     1870
# 4             5       3600      1740        4560         7760     1560
#
#    moisturizer  total_units  total_profit
# 0         1500        21100        211000
# 1         1200        18330        183300
# 2         1340        22470        224700
# 3         1130        22270        222700
# 4         1740        20960        209600

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('/content/drive/MyDrive/Classroom/CSE303/company_sales_data.csv')
df
months  = df ['month_number'].tolist()
faceCream   = df ['facecream'].tolist()
faceWash   = df ['facewash'].tolist()
toothPaste = df ['toothpaste'].tolist()
bathingsoap   = df ['bathingsoap'].tolist()
shampoo   = df ['shampoo'].tolist()
moisturizer = df ['moisturizer'].tolist()

plt.plot(months, faceCream,  label = 'Face cream Sales Data', marker='o', linewidth=3)
plt.plot(months, faceWash,  label = 'Face Wash Sales Data',  marker='o', linewidth=3)
plt.plot(months, toothPaste,label = 'ToothPaste Sales Data', marker='o', linewidth=3)
plt.plot(months, bathingsoap,label = 'ToothPaste Sales Data', marker='o', linewidth=3)
plt.plot(months, shampoo, label = 'ToothPaste Sales Data', marker='o', linewidth=3)
plt.plot(months, moisturizer, label = 'ToothPaste Sales Data', marker='o', linewidth=3)



plt.title('Sales data')
plt.legend(loc='upper left')
plt.xlabel('Month Number')
plt.ylabel('Sales units in number')
plt.xticks(months)
plt.yticks([1000, 2000, 4000, 6000, 8000, 10000, 12000, 15000, 18000])
plt.show()

# %% [markdown]
# # Exercise 3:
# Read face cream and facewash product sales data and show it using the bar chart
# The bar chart should display the number of units sold per month for each product. Add a separate bar for each product in the same chart.
#
# The bar chart should look like this.
#
# ![image.png](data:image/png;base64,...)

# %%
# Code Here
sales_data = df[['facecream','facewash']]

ax = sales_data.plot.bar(color={'facecream':'red', 'facewash':'blue'})
ax.set_xlabel('Month number')
ax.set_ylabel('Sales unit in number')
ax.set_title('facecream and facewash sales data')
ax.legend(['Face Cream Sales Data','Face Wash Sales Data'],loc='upper left')
plt.show();

# %% [markdown]
# # Exercise 4:
# Calculate total sale data for last year for each product and show it using a Pie chart
# Note: In Pie chart display Number of units sold per year for each product in percentage.
#
# The Pie chart should look like this.
#
# ![image.png](data:image/png;base64,...)

# %%
df.head(2)
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0             1       2500      1500        5200         9200     1200
# 1             2       2630      1200        5100         6100     2100
#
#    moisturizer  total_units  total_profit
# 0         1500        21100        211000
# 1         1200        18330        183300

# %%
# Code Here
df = pd.read_csv('/content/drive/MyDrive/Classroom/CSE303/company_sales_data.csv')
monthList  = df ['month_number'].tolist()

facecream = df ['facecream'].sum()
facewash = df['facewash'].sum()
toothpaste = df ['toothpaste'].sum()
bathingsoap = df ['bathingsoap'].sum()
shampoo = df['shampoo'].sum()
moisturizer = df['moisturizer'].sum()

legends = ['FaceCream', 'FaseWash', 'ToothPaste', 'Bathing soap', 'Shampoo', 'Moisturizer']
salesData  = [ facecream, facewash, toothpaste, bathingsoap,shampoo, moisturizer]
plt.axis("equal")
plt.pie(salesData, labels=legends, autopct='%1.1f%%')
plt.title('Sales data')
plt.legend(loc='lower right')
plt.show()

# %% [markdown]
# # Exercise 5:
# Plot Sine and Cosine Graph.
#
# The plot graph should look like this.
#
# ![image.png](data:image/png;base64,...)

# %%
# Code Here
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
np.random.seed(42)
x = np.arange(-np.pi, np.pi,0.1)
y = np.arange(-np.pi, np.pi,0.1)
sin_x = np.sin(x)
cos_x = np.cos(y)

# Plot a sine wave using time and amplitude obtained for the sine wave

plt.plot(x, sin_x, color='blue')
plt.plot(y, cos_x, color='green')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.legend(['cosine', 'sine'], loc='upper left')
plt.show()
